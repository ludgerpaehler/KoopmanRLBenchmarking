# %% [markdown]
# # Main Episodic Returns Plot

# %%
import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Define the global Matplotlib settings

# %%
# Global settings for MatPlotlib
plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams['xtick.major.pad']='8'
plt.rcParams['ytick.major.pad']='8'
plt.rcParams["axes.labelpad"]='10'

# Use the same Font as LaTeX
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['cmr10']
plt.rcParams["text.usetex"] = True
plt.rcParams["axes.formatter.use_mathtext"] = True

# %% [markdown]
# Define the color palate

# %%
lqr_color = '#FFBE0B'
skvi_color = '#FB5607'
sac_q_color = '#FF006E'
sac_v_color = '#8338EC'
sakc_color = '#3A86FF'

# %% [markdown]
# Setting the Path to the folders

# %% [markdown]
# Linear System:

# %%
data_linear_system_lqr = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/LinearSystem/LQR/episodic_returns.parquet.gz"
data_linear_system_skvi = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/LinearSystem/SKVI/episodic_returns.parquet.gz"
data_linear_system_sac_q = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/LinearSystem/SAC_Q/episodic_returns.parquet.gz"
data_linear_system_sac_v = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/LinearSystem/SAC_V/episodic_returns.parquet.gz"
data_linear_system_sakc = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/LinearSystem/SAKC/episodic_returns.parquet.gz"

# %% [markdown]
# Fluid Flow

# %%
data_fluid_flow_lqr = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/FluidFlow/LQR/episodic_returns.parquet.gz"
data_fluid_flow_skvi = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/FluidFlow/SKVI/episodic_returns.parquet.gz"
data_fluid_flow_sac_q = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/FluidFlow/SAC_Q/episodic_returns.parquet.gz"
data_fluid_flow_sac_v = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/FluidFlow/SAC_V/episodic_returns.parquet.gz"
data_fluid_flow_sakc = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/FluidFlow/SAKC/episodic_returns.parquet.gz"

# %% [markdown]
# Lorenz

# %%
data_lorenz_lqr = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/Lorenz/LQR/episodic_returns.parquet.gz"
data_lorenz_skvi = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/Lorenz/SKVI/episodic_returns.parquet.gz"
data_lorenz_sac_q = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/Lorenz/SAC_Q/episodic_returns.parquet.gz"
data_lorenz_sac_v = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/Lorenz/SAC_V/episodic_returns.parquet.gz"
data_lorenz_sakc = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/Lorenz/SAKC/episodic_returns.parquet.gz"

# %% [markdown]
# (Stochastic) Double Well

# %%
data_double_well_lqr = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/DoubleWell/LQR/episodic_returns.parquet.gz"
data_double_well_skvi = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/DoubleWell/SKVI/episodic_returns.parquet.gz"
data_double_well_sac_q = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/DoubleWell/SAC_Q/episodic_returns.parquet.gz"
data_double_well_sac_v = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/DoubleWell/SAC_V/episodic_returns.parquet.gz"
data_double_well_sakc = "/Users/lpaehler/Work/ReinforcementLearning/KoopmanRL/DataLogs/EpisodicReturns50/DoubleWell/SAKC/episodic_returns.parquet.gz"

# %% [markdown]
# Loading the respective files into their dataframes

# %%
# Loading in the dataframes for the Linear System
lqr_linear_system_df = pd.read_parquet(data_linear_system_lqr)
skvi_linear_system_df = pd.read_parquet(data_linear_system_skvi)
sac_q_linear_system_df = pd.read_parquet(data_linear_system_sac_q)
sac_v_linear_system_df = pd.read_parquet(data_linear_system_sac_v)
sakc_linear_system_df = pd.read_parquet(data_linear_system_sakc)

# Loading in the dataframes for the Fluid Flow
lqr_fluid_flow_df = pd.read_parquet(data_fluid_flow_lqr)
skvi_fluid_flow_df = pd.read_parquet(data_fluid_flow_skvi)
sac_q_fluid_flow_df = pd.read_parquet(data_fluid_flow_sac_q)
sac_v_fluid_flow_df = pd.read_parquet(data_fluid_flow_sac_v)
sakc_fluid_flow_df = pd.read_parquet(data_fluid_flow_sakc)

# Loading in the dataframes for the Lorenz System
lqr_lorenz_df = pd.read_parquet(data_lorenz_lqr)
skvi_lorenz_df = pd.read_parquet(data_lorenz_skvi)
sac_q_lorenz_df = pd.read_parquet(data_lorenz_sac_q)
sac_v_lorenz_df = pd.read_parquet(data_lorenz_sac_v)
sakc_lorenz_df = pd.read_parquet(data_lorenz_sakc)

# Loading in the dataframes for the Double Well
lqr_double_well_df = pd.read_parquet(data_double_well_lqr)
skvi_double_well_df = pd.read_parquet(data_double_well_skvi)
sac_q_double_well_df = pd.read_parquet(data_double_well_sac_q)
sac_v_double_well_df = pd.read_parquet(data_double_well_sac_v)
sakc_double_well_df = pd.read_parquet(data_double_well_sakc)

# %% [markdown]
# Define the universal index for all plots

# %%
xs = skvi_fluid_flow_df.index

# %%
sakc_linear_system_df.max(axis=None)
# Out:
# -16.256811141967773

# %% [markdown]
# Calculate all means, and standard deviations for the plotting

# %% [markdown]
# Linear System:

# %%
# Values for the plotting of the linear system

# LQR
ymean_linear_system_lqr = lqr_linear_system_df.mean(axis=1)
ystd_linear_system_lqr = lqr_linear_system_df.std(axis=1)

# SKVI
ymean_linear_system_skvi = skvi_linear_system_df.mean(axis=1)
ystd_linear_system_skvi = skvi_linear_system_df.std(axis=1)

# SAC (Q)
ymean_linear_system_sac_q = sac_q_linear_system_df.mean(axis=1)
ystd_linear_system_sac_q = sac_q_linear_system_df.std(axis=1)

# SAC (V)
ymean_linear_system_sac_v = sac_v_linear_system_df.mean(axis=1)
ystd_linear_system_sac_v = sac_v_linear_system_df.std(axis=1)

# SAKC
ymean_linear_system_sakc = sakc_linear_system_df.mean(axis=1)
ystd_linear_system_sakc = sakc_linear_system_df.std(axis=1)

# Optimal return
linear_system_optimal = np.max([
    lqr_linear_system_df.max(axis=None),
    skvi_linear_system_df.max(axis=None),
    sac_q_linear_system_df.max(axis=None),
    sac_v_linear_system_df.max(axis=None),
    sakc_linear_system_df.max(axis=None)
])

# %%
ystd_linear_system_sac_v
# Out:
# 199       96770.972344
# 399      147250.165446
# 599      177282.455806
# 799       95104.746108
# 999      118547.167985
#              ...
# 49199       715.438222
# 49399       676.976910
# 49599       558.434106
# 49799       691.428495
# 49999       717.854692
# Length: 250, dtype: float64

# %%
ystd_linear_system_lqr = ystd_linear_system_lqr.clip(upper=50000)
ystd_linear_system_sac_q = ystd_linear_system_sac_q.clip(upper=50000)
ystd_linear_system_sac_v = ystd_linear_system_sac_v.clip(upper=50000)
ystd_linear_system_sakc = ystd_linear_system_sakc.clip(upper=50000)
ystd_linear_system_skvi = ystd_linear_system_skvi.clip(upper=50000)

# %% [markdown]
# Fluid Flow:

# %%
# Values for the plotting of the fluid flow

# LQR
ymean_fluid_flow_lqr = lqr_fluid_flow_df.mean(axis=1)
ystd_fluid_flow_lqr = lqr_fluid_flow_df.std(axis=1)

# SKVI
ymean_fluid_flow_skvi = skvi_fluid_flow_df.mean(axis=1)
ystd_fluid_flow_skvi = skvi_fluid_flow_df.std(axis=1)

# SAC (Q)
ymean_fluid_flow_sac_q = sac_q_fluid_flow_df.mean(axis=1)
ystd_fluid_flow_sac_q = sac_q_fluid_flow_df.std(axis=1)

# SAC (V)
ymean_fluid_flow_sac_v = sac_v_fluid_flow_df.mean(axis=1)
ystd_fluid_flow_sac_v = sac_v_fluid_flow_df.std(axis=1)

# SAKC
ymean_fluid_flow_sakc = sakc_fluid_flow_df.mean(axis=1)
ystd_fluid_flow_sakc = sakc_fluid_flow_df.std(axis=1)

# Optimal return
fluid_flow_optimal = np.max([
    lqr_fluid_flow_df.max(axis=None),
    skvi_fluid_flow_df.max(axis=None),
    sac_q_fluid_flow_df.max(axis=None),
    sac_v_fluid_flow_df.max(axis=None),
    sakc_fluid_flow_df.max(axis=None)
])

# %% [markdown]
# Lorenz System:

# %%
# Values for the plotting of the Lorenz system

# LQR
ymean_lorenz_lqr = lqr_lorenz_df.mean(axis=1)
ystd_lorenz_lqr = lqr_lorenz_df.std(axis=1)

# SKVI
ymean_lorenz_skvi = skvi_lorenz_df.mean(axis=1)
ystd_lorenz_skvi = skvi_lorenz_df.std(axis=1)

# SAC (Q)
ymean_lorenz_sac_q = sac_q_lorenz_df.mean(axis=1)
ystd_lorenz_sac_q = sac_q_lorenz_df.std(axis=1)

# SAC (V)
ymean_lorenz_sac_v = sac_v_lorenz_df.mean(axis=1)
ystd_lorenz_sac_v = sac_v_lorenz_df.std(axis=1)

# SAKC
ymean_lorenz_sakc = sakc_lorenz_df.mean(axis=1)
ystd_lorenz_sakc = sakc_lorenz_df.std(axis=1)

# Optimal return
lorenz_optimal = np.max([
    lqr_lorenz_df.max(axis=None),
    skvi_lorenz_df.max(axis=None),
    sac_q_lorenz_df.max(axis=None),
    sac_v_lorenz_df.max(axis=None),
    sakc_lorenz_df.max(axis=None)
])

# %% [markdown]
# Double Well:

# %%
# Values for the plotting of the Double Well

# LQR
ymean_double_well_lqr = lqr_double_well_df.mean(axis=1)
ystd_double_well_lqr = lqr_double_well_df.std(axis=1)

# SKVI
ymean_double_well_skvi = skvi_double_well_df.mean(axis=1)
ystd_double_well_skvi = skvi_double_well_df.std(axis=1)

# SAC (Q)
ymean_double_well_sac_q = sac_q_double_well_df.mean(axis=1)
ystd_double_well_sac_q = sac_q_double_well_df.std(axis=1)

# SAC (V)
ymean_double_well_sac_v = sac_v_double_well_df.mean(axis=1)
ystd_double_well_sac_v = sac_v_double_well_df.std(axis=1)

# SAKC
ymean_double_well_sakc = sakc_double_well_df.mean(axis=1)
ystd_double_well_sakc = sakc_double_well_df.std(axis=1)

# Optimal return
double_well_optimal = np.max([
    lqr_double_well_df.max(axis=None),
    skvi_double_well_df.max(axis=None),
    sac_q_double_well_df.max(axis=None),
    sac_v_double_well_df.max(axis=None),
    sakc_double_well_df.max(axis=None)
])

# %% [markdown]
# Big Figure

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 16), sharex=True)

# Linear System
axes[0, 0].plot(lqr_linear_system_df.index, ymean_linear_system_lqr, color=lqr_color, label="LQR")
axes[0, 0].fill_between(lqr_linear_system_df.index, ymean_linear_system_lqr - ystd_linear_system_lqr, (ymean_linear_system_lqr + ystd_linear_system_lqr).clip(upper=linear_system_optimal), color=lqr_color, alpha=.2)
axes[0, 0].plot(skvi_linear_system_df.index, ymean_linear_system_skvi, color=skvi_color, label="SKVI")
axes[0, 0].fill_between(skvi_linear_system_df.index, ymean_linear_system_skvi - ystd_linear_system_skvi, (ymean_linear_system_skvi + ystd_linear_system_skvi).clip(upper=linear_system_optimal), color=skvi_color, alpha=.2)
axes[0, 0].plot(sac_q_linear_system_df.index, ymean_linear_system_sac_q, color=sac_q_color, label="SAC (Q)")
axes[0, 0].fill_between(sac_q_linear_system_df.index, ymean_linear_system_sac_q - ystd_linear_system_sac_q, (ymean_linear_system_sac_q + ystd_linear_system_sac_q).clip(upper=linear_system_optimal), color=sac_q_color, alpha=.2)
axes[0, 0].plot(sac_v_linear_system_df.index, ymean_linear_system_sac_v, color=sac_v_color, label="SAC (V)")
axes[0, 0].fill_between(sac_v_linear_system_df.index, ymean_linear_system_sac_v - ystd_linear_system_sac_v, (ymean_linear_system_sac_v + ystd_linear_system_sac_v).clip(upper=linear_system_optimal), color=sac_v_color, alpha=.2)
axes[0, 0].plot(sakc_linear_system_df.index, ymean_linear_system_sakc, color=sakc_color, label="SAKC")
axes[0, 0].fill_between(sakc_linear_system_df.index, ymean_linear_system_sakc - ystd_linear_system_sakc, (ymean_linear_system_sakc + ystd_linear_system_sakc).clip(upper=linear_system_optimal), color=sakc_color, alpha=.2)
axes[0, 0].set_title('Linear System', fontsize=24, pad=20)
axes[0, 0].axhline(linear_system_optimal, linestyle='-.', color='black', linewidth=0.5, label="Optimal Return")

# Fluid Flow
axes[0, 1].plot(lqr_fluid_flow_df.index, ymean_fluid_flow_lqr, color=lqr_color)
axes[0, 1].fill_between(lqr_fluid_flow_df.index, ymean_fluid_flow_lqr - ystd_fluid_flow_lqr, (ymean_fluid_flow_lqr + ystd_fluid_flow_lqr).clip(upper=fluid_flow_optimal), color=lqr_color, alpha=.2)
axes[0, 1].plot(skvi_fluid_flow_df.index, ymean_fluid_flow_skvi, color=skvi_color)
axes[0, 1].fill_between(skvi_fluid_flow_df.index, ymean_fluid_flow_skvi - ystd_fluid_flow_skvi, (ymean_fluid_flow_skvi + ystd_fluid_flow_skvi).clip(upper=fluid_flow_optimal), color=skvi_color, alpha=.2)
axes[0, 1].plot(sac_q_fluid_flow_df.index, ymean_fluid_flow_sac_q, color=sac_q_color)
axes[0, 1].fill_between(sac_q_fluid_flow_df.index, ymean_fluid_flow_sac_q - ystd_fluid_flow_sac_q, (ymean_fluid_flow_sac_q + ystd_fluid_flow_sac_q).clip(upper=fluid_flow_optimal), color=sac_q_color, alpha=.2)
axes[0, 1].plot(sac_v_fluid_flow_df.index, ymean_fluid_flow_sac_v, color=sac_v_color)
axes[0, 1].fill_between(sac_v_fluid_flow_df.index, ymean_fluid_flow_sac_v - ystd_fluid_flow_sac_v, (ymean_fluid_flow_sac_v + ystd_fluid_flow_sac_v).clip(upper=fluid_flow_optimal), color=sac_v_color, alpha=.2)
axes[0, 1].plot(sakc_fluid_flow_df.index, ymean_fluid_flow_sakc, color=sakc_color)
axes[0, 1].fill_between(sakc_fluid_flow_df.index, ymean_fluid_flow_sakc - ystd_fluid_flow_sakc, (ymean_fluid_flow_sakc + ystd_fluid_flow_sakc).clip(upper=fluid_flow_optimal), color=sakc_color, alpha=.2)
axes[0, 1].set_title('Fluid Flow', fontsize=24, pad=20)
axes[0, 1].axhline(fluid_flow_optimal, linestyle='-.', color='black', linewidth=0.5)

# Lorenz
axes[1, 0].plot(lqr_lorenz_df.index, ymean_lorenz_lqr, color=lqr_color)
axes[1, 0].fill_between(lqr_lorenz_df.index, ymean_lorenz_lqr - ystd_lorenz_lqr, (ymean_lorenz_lqr + ystd_lorenz_lqr).clip(upper=lorenz_optimal), color=lqr_color, alpha=.2)
axes[1, 0].plot(skvi_lorenz_df.index, ymean_lorenz_skvi, color=skvi_color)
axes[1, 0].fill_between(skvi_lorenz_df.index, ymean_lorenz_skvi - ystd_lorenz_skvi, (ymean_lorenz_skvi + ystd_lorenz_skvi).clip(upper=lorenz_optimal), color=skvi_color, alpha=.2)
axes[1, 0].plot(sac_q_lorenz_df.index, ymean_lorenz_sac_q, color=sac_q_color)
axes[1, 0].fill_between(sac_q_lorenz_df.index, ymean_lorenz_sac_q - ystd_lorenz_sac_q, (ymean_lorenz_sac_q + ystd_lorenz_sac_q).clip(upper=lorenz_optimal), color=sac_q_color, alpha=.2)
axes[1, 0].plot(sac_v_lorenz_df.index, ymean_lorenz_sac_v, color=sac_v_color)
axes[1, 0].fill_between(sac_v_lorenz_df.index, ymean_lorenz_sac_v - ystd_lorenz_sac_v, (ymean_lorenz_sac_v + ystd_lorenz_sac_v).clip(upper=lorenz_optimal), color=sac_v_color, alpha=.2)
axes[1, 0].plot(sakc_lorenz_df.index, ymean_lorenz_sakc, color=sakc_color)
axes[1, 0].fill_between(sakc_lorenz_df.index, ymean_lorenz_sakc - ystd_lorenz_sakc, (ymean_lorenz_sakc + ystd_lorenz_sakc).clip(upper=lorenz_optimal), color=sakc_color, alpha=.2)
axes[1, 0].set_title('Lorenz', fontsize=24, pad=20)
axes[1, 0].axhline(lorenz_optimal, linestyle='-.', color='black', linewidth=0.5)

# Double Well
axes[1, 1].plot(lqr_double_well_df.index, ymean_double_well_lqr, color=lqr_color)
axes[1, 1].fill_between(lqr_double_well_df.index, ymean_double_well_lqr - ystd_double_well_lqr, (ymean_double_well_lqr + ystd_double_well_lqr).clip(upper=double_well_optimal), color=lqr_color, alpha=.2)
axes[1, 1].plot(skvi_double_well_df.index, ymean_double_well_skvi, color=skvi_color)
axes[1, 1].fill_between(skvi_double_well_df.index, ymean_double_well_skvi - ystd_double_well_skvi, (ymean_double_well_skvi + ystd_double_well_skvi).clip(upper=double_well_optimal), color=skvi_color, alpha=.2)
axes[1, 1].plot(sac_q_double_well_df.index, ymean_double_well_sac_q, color=sac_q_color)
axes[1, 1].fill_between(sac_q_double_well_df.index, ymean_double_well_sac_q - ystd_double_well_sac_q, (ymean_double_well_sac_q + ystd_double_well_sac_q).clip(upper=double_well_optimal), color=sac_q_color, alpha=.2)
axes[1, 1].plot(sac_v_double_well_df.index, ymean_double_well_sac_v, color=sac_v_color)
axes[1, 1].fill_between(sac_v_double_well_df.index, ymean_double_well_sac_v - ystd_double_well_sac_v, (ymean_double_well_sac_v + ystd_double_well_sac_v).clip(upper=double_well_optimal), color=sac_v_color, alpha=.2)
axes[1, 1].plot(sakc_double_well_df.index, ymean_double_well_sakc, color=sakc_color)
axes[1, 1].fill_between(sakc_double_well_df.index, ymean_double_well_sakc - ystd_double_well_sakc, (ymean_double_well_sakc + ystd_double_well_sakc).clip(upper=double_well_optimal), color=sakc_color, alpha=.2)
axes[1, 1].set_title('Double Well', fontsize=24, pad=20)
axes[1, 1].axhline(double_well_optimal, linestyle='-.', color='black', linewidth=0.5)

# Force the tick formatting to be the same for all subplots
axes[0, 1].ticklabel_format(style='sci', axis='y', scilimits=(0,0))
axes[1, 1].ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# Legend
fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.98), ncol=6, fontsize=22, frameon=False)

# Major x-, and y-labels
fig.supxlabel('Steps in Environment', fontsize=24, y=0.04)
fig.supylabel('Episodic Return', fontsize=24, x=0.06)
# Out:
# Text(0.06, 0.5, 'Episodic Return')

# %% [markdown]
# The y-axis
